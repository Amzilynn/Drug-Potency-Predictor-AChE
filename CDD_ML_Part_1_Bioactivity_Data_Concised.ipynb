# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.11/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.3.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.12.14)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.3.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.17.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('SARS-CoV-2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 3018                                                 []
# 3019                                                 []
# 3020                                                 []
# 3021                                                 []
# 3022  [{'xref_id': 'CPX-3270', 'xref_name': 'IkappaB...
#
#                                                organism  \
# 0       Severe acute respiratory syndrome coronavirus 2
# 1     Severe acute respiratory syndrome-related coro...
# 2                                          Homo sapiens
# 3                                          Homo sapiens
# 4                                     Rattus norvegicus
# ...                                                 ...
# 3018                                       Mus musculus
# 3019                                       Mus musculus
# 3020                                  Rattus norvegicus
# 3021                                       Homo sapiens
# 3022                                       Mus musculus
#
#                                 pref_name  score  species_group_flag  \
# 0                              SARS-CoV-2   34.0               False
# 1                                SARS-CoV   34.0               False
# 2        Serine--tRNA ligase, cytoplasmic   15.0               False
# 3                  Thromboxane-A synthase   14.0               False
# 4                  Thromboxane-A synthase   14.0               False
# ...                                   ...    ...                 ...
# 3018              Glutamate NMDA receptor    0.0               False
# 3019               L-type calcium channel    0.0               False
# 3020         Voltage-gated sodium channel    0.0               False
# 3021  UDP-glucuronosyltransferases (UGTs)    0.0               False
# 3022                     I-kappa-B kinase    0.0               False
#
#      target_chembl_id                                  target_components  \
# 0       CHEMBL4303835                                                 []
# 1       CHEMBL4303836                                                 []
# 2       CHEMBL4523232  [{'accession': 'P49591', 'component_descriptio...
# 3          CHEMBL1835  [{'accession': 'P24557', 'component_descriptio...
# 4          CHEMBL4028  [{'accession': 'P49430', 'component_descriptio...
# ...               ...                                                ...
# 3018    CHEMBL3832634  [{'accession': 'P35436', 'component_descriptio...
# 3019    CHEMBL3988632  [{'accession': 'Q01815', 'component_descriptio...
# 3020    CHEMBL3988641  [{'accession': 'O88457', 'component_descriptio...
# 3021    CHEMBL4523985  [{'accession': 'P22310', 'component_descriptio...
# 3022    CHEMBL4524000  [{'accession': 'Q60680', 'component_descriptio...
#
#                 target_type     tax_id
# 0                  ORGANISM  2697049.0
# 1                  ORGANISM   694009.0
# 2            SINGLE PROTEIN     9606.0
# 3            SINGLE PROTEIN     9606.0
# 4            SINGLE PROTEIN    10116.0
# ...                     ...        ...
# 3018  PROTEIN COMPLEX GROUP    10090.0
# 3019         PROTEIN FAMILY    10090.0
# 3020         PROTEIN FAMILY    10116.0
# 3021         PROTEIN FAMILY     9606.0
# 3022        PROTEIN COMPLEX    10090.0
#
# [3023 rows x 9 columns]

# %%
targets.shape
# Out:
# (3023, 9)

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL4028'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       192051                  []
# 1        None             None       192052                  []
# 2        None             None       200255                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL809686  Tested in vitro against TXA2 synthetase inhibi...
# 1    CHEMBL880941  Tested in vitro against TXA2 synthetase inhibi...
# 2    CHEMBL809686  Tested in vitro against TXA2 synthetase inhibi...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#      target_organism        target_pref_name target_tax_id text_value  toid  \
# 0  Rattus norvegicus  Thromboxane-A synthase         10116       None  None
# 1  Rattus norvegicus  Thromboxane-A synthase         10116       None  None
# 2  Rattus norvegicus  Thromboxane-A synthase         10116       None  None
#
#    type units    uo_units upper_value value
# 0  IC50    uM  UO_0000065        None   0.3
# 1  IC50    uM  UO_0000065        None   3.3
# 2  IC50    uM  UO_0000065        None   0.2
#
# [3 rows x 46 columns]

# %%
df.shape
# Out:
# (205, 46)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data_raw.csv "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# total 95
# -rw------- 1 root root 96462 Jan 20 22:14 bioactivity_data_raw.csv

# %%
! ls
# Out:
# bioactivity_data_preprocessed.csv  bioactivity_data_raw.csv  gdrive  sample_data

# %%
! head bioactivity_data_raw.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,192051,[],CHEMBL809686,Tested in vitro against TXA2 synthetase inhibitory activity in rat platelet,B,,,BAO_0000190,BAO_0000019,assay format,Cn1nc(-c2cncs2)c2ccccc2c1=O,,,CHEMBL1126557,J Med Chem,1993,"{'bei': '26.81', 'le': '0.52', 'lle': '4.46', 'sei': '13.65'}",CHEMBL130453,,CHEMBL130453,6.52,0,http://www.openphacts.org/units/Nanomolar,251014,=,1,1,=,,IC50,nM,,300.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,uM,UO_0000065,,0.3
# ,,192052,[],CHEMBL880941,Tested in vitro against TXA2 synthetase inhibitory activity in rat whole blood,B,,,BAO_0000190,BAO_0000221,tissue-based format,Cn1nc(-c2cncs2)c2ccccc2c1=O,,,CHEMBL1126557,J Med Chem,1993,"{'bei': '22.53', 'le': '0.44', 'lle': '3.42', 'sei': '11.47'}",CHEMBL130453,,CHEMBL130453,5.48,0,http://www.openphacts.org/units/Nanomolar,251014,=,1,1,=,,IC50,nM,,3300.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,uM,UO_0000065,,3.3
# ,,200255,[],CHEMBL809686,Tested in vitro against TXA2 synthetase inhibitory activity in rat platelet,B,,,BAO_0000190,BAO_0000019,assay format,O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1,,,CHEMBL1126557,J Med Chem,1993,"{'bei': '29.35', 'le': '0.54', 'lle': '4.67', 'sei': '12.15'}",CHEMBL11662,OZAGREL,CHEMBL11662,6.70,0,http://www.openphacts.org/units/Nanomolar,251007,=,1,1,=,,IC50,nM,,200.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,uM,UO_0000065,,0.2
# ,,200256,[],CHEMBL880941,Tested in vitro against TXA2 synthetase inhibitory activity in rat whole blood,B,,,BAO_0000190,BAO_0000221,tissue-based format,O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1,,,CHEMBL1126557,J Med Chem,1993,"{'bei': '29.35', 'le': '0.54', 'lle': '4.67', 'sei': '12.15'}",CHEMBL11662,OZAGREL,CHEMBL11662,6.70,0,http://www.openphacts.org/units/Nanomolar,251007,=,1,1,=,,IC50,nM,,200.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,uM,UO_0000065,,0.2
# ,,218108,[],CHEMBL809686,Tested in vitro against TXA2 synthetase inhibitory activity in rat platelet,B,,,BAO_0000190,BAO_0000019,assay format,CCn1nc(-c2cccnc2)c2ccccc2c1=O,,,CHEMBL1126557,J Med Chem,1993,"{'bei': '23.42', 'le': '0.42', 'lle': '3.41', 'sei': '12.32'}",CHEMBL335687,,CHEMBL335687,5.89,0,http://www.openphacts.org/units/Nanomolar,251036,=,1,1,=,,IC50,nM,,1300.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,uM,UO_0000065,,1.3
# ,,218109,[],CHEMBL880941,Tested in vitro against TXA2 synthetase inhibitory activity in rat whole blood,B,,,BAO_0000190,BAO_0000221,tissue-based format,CCn1nc(-c2cccnc2)c2ccccc2c1=O,,,CHEMBL1126557,J Med Chem,1993,"{'bei': '22.96', 'le': '0.41', 'lle': '3.29', 'sei': '12.08'}",CHEMBL335687,,CHEMBL335687,5.77,0,http://www.openphacts.org/units/Nanomolar,251036,=,1,1,=,,IC50,nM,,1700.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,uM,UO_0000065,,1.7
# ,,222497,[],CHEMBL814402,Compound was tested for inhibitory activity against thromboxane synthetase,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(NCCCCn1ccnc1)c1ccc(Cl)cc1,,,CHEMBL1123157,J Med Chem,1986,"{'bei': '19.08', 'le': '0.38', 'lle': '2.55', 'sei': '11.30'}",CHEMBL151732,,CHEMBL151732,5.30,0,http://www.openphacts.org/units/Nanomolar,293140,=,1,1,=,,IC50,nM,,5000.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,M,UO_0000065,,0.000005
# ,,224014,[],CHEMBL814405,Inhibition of thromboxane formation at a concentration of 10e -6 M.,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(NCCCCCCCCn1ccnc1)c1ccc(Cl)s1,,,CHEMBL1123758,J Med Chem,1987,"{'bei': '21.05', 'le': '0.44', 'lle': '2.78', 'sei': '15.25'}",CHEMBL9088,,CHEMBL9088,7.16,0,http://www.openphacts.org/units/Nanomolar,4634,=,1,1,=,,IC50,nM,,70.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,M,UO_0000065,,7E-8
# ,,226533,[],CHEMBL814405,Inhibition of thromboxane formation at a concentration of 10e -6 M.,B,,,BAO_0000190,BAO_0000357,single protein format,CC(CCNC(=O)c1ccc(Cl)s1)n1ccnc1,,,CHEMBL1123758,J Med Chem,1987,"{'bei': '20.08', 'le': '0.43', 'lle': '2.72', 'sei': '12.15'}",CHEMBL8515,,CHEMBL8515,5.70,0,http://www.openphacts.org/units/Nanomolar,4621,=,1,1,=,,IC50,nM,,2000.0,CHEMBL4028,Rattus norvegicus,Thromboxane-A synthase,10116,,,IC50,uM,UO_0000065,,2.0

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df.isnull().sum()
# Out:
# action_type                  205
# activity_comment             205
# activity_id                    0
# activity_properties            0
# assay_chembl_id                0
# assay_description              0
# assay_type                     0
# assay_variant_accession      205
# assay_variant_mutation       205
# bao_endpoint                   0
# bao_format                     0
# bao_label                      0
# canonical_smiles               0
# data_validity_comment        205
# data_validity_description    205
# document_chembl_id             0
# document_journal               0
# document_year                  0
# ligand_efficiency             66
# molecule_chembl_id             0
# molecule_pref_name           189
# parent_molecule_chembl_id      0
# pchembl_value                 31
# potential_duplicate            0
# qudt_units                     0
# record_id                      0
# relation                       0
# src_id                         0
# standard_flag                  0
# standard_relation              0
# standard_text_value          205
# standard_type                  0
# standard_units                 0
# standard_upper_value         205
# standard_value                 0
# target_chembl_id               0
# target_organism                0
# target_pref_name               0
# target_tax_id                  0
# text_value                   205
# toid                         205
# type                           0
# units                          0
# uo_units                       0
# upper_value                  205
# value                          0
# dtype: int64

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None       192051                  []
# 1          None             None       192052                  []
# 2          None             None       200255                  []
# 3          None             None       200256                  []
# 4          None             None       218108                  []
# ..          ...              ...          ...                 ...
# 200        None             None       900764                  []
# 201        None             None       900766                  []
# 202        None             None       900768                  []
# 203        None             None       900770                  []
# 204        None             None       904131                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL809686  Tested in vitro against TXA2 synthetase inhibi...
# 1      CHEMBL880941  Tested in vitro against TXA2 synthetase inhibi...
# 2      CHEMBL809686  Tested in vitro against TXA2 synthetase inhibi...
# 3      CHEMBL880941  Tested in vitro against TXA2 synthetase inhibi...
# 4      CHEMBL809686  Tested in vitro against TXA2 synthetase inhibi...
# ..              ...                                                ...
# 200    CHEMBL814434  Tested for inhibition of thromboxane synthetas...
# 201    CHEMBL814434  Tested for inhibition of thromboxane synthetas...
# 202    CHEMBL814434  Tested for inhibition of thromboxane synthetas...
# 203    CHEMBL814434  Tested for inhibition of thromboxane synthetas...
# 204    CHEMBL815558  Inhibitory effect against thromboxane A2 synth...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 200          B                    None                   None  BAO_0000190
# 201          B                    None                   None  BAO_0000190
# 202          B                    None                   None  BAO_0000190
# 203          B                    None                   None  BAO_0000190
# 204          B                    None                   None  BAO_0000190
#
#      ...    target_organism        target_pref_name target_tax_id text_value  \
# 0    ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 1    ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 2    ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 3    ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 4    ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# ..   ...                ...                     ...           ...        ...
# 200  ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 201  ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 202  ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 203  ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
# 204  ...  Rattus norvegicus  Thromboxane-A synthase         10116       None
#
#      toid  type units    uo_units upper_value     value
# 0    None  IC50    uM  UO_0000065        None       0.3
# 1    None  IC50    uM  UO_0000065        None       3.3
# 2    None  IC50    uM  UO_0000065        None       0.2
# 3    None  IC50    uM  UO_0000065        None       0.2
# 4    None  IC50    uM  UO_0000065        None       1.3
# ..    ...   ...   ...         ...         ...       ...
# 200  None  IC50     M  UO_0000065        None      3E-8
# 201  None  IC50     M  UO_0000065        None  0.000001
# 202  None  IC50     M  UO_0000065        None      9E-8
# 203  None  IC50     M  UO_0000065        None    3.4E-7
# 204  None  IC50    nM  UO_0000065        None     850.0
#
# [205 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("inactive")

# %% [markdown]
# **Iterate the molecule_chembl_id to a list**

# %%
mol_cid =[]
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL130453',
#  'CHEMBL130453',
#  'CHEMBL11662',
#  'CHEMBL11662',
#  'CHEMBL335687',
#  'CHEMBL335687',
#  'CHEMBL151732',
#  'CHEMBL9088',
#  'CHEMBL8515',
#  'CHEMBL8778',
#  'CHEMBL150316',
#  'CHEMBL8976',
#  'CHEMBL8887',
#  'CHEMBL267978',
#  'CHEMBL406693',
#  'CHEMBL417603',
#  'CHEMBL8870',
#  'CHEMBL8735',
#  'CHEMBL267473',
#  'CHEMBL147183',
#  'CHEMBL147413',
#  'CHEMBL268645',
#  'CHEMBL355929',
#  'CHEMBL8648',
#  'CHEMBL8489',
#  'CHEMBL148928',
#  'CHEMBL8879',
#  'CHEMBL8819',
#  'CHEMBL8986',
#  'CHEMBL267473',
#  'CHEMBL8957',
#  'CHEMBL358777',
#  'CHEMBL345310',
#  'CHEMBL8987',
#  'CHEMBL8679',
#  'CHEMBL333219',
#  'CHEMBL93',
#  'CHEMBL116719',
#  'CHEMBL23942',
#  'CHEMBL267473',
#  'CHEMBL22542',
#  'CHEMBL123307',
#  'CHEMBL330837',
#  'CHEMBL120250',
#  'CHEMBL280728',
#  'CHEMBL121306',
#  'CHEMBL444856',
#  'CHEMBL120249',
#  'CHEMBL120904',
#  'CHEMBL118619',
#  'CHEMBL122181',
#  'CHEMBL120181',
#  'CHEMBL121307',
#  'CHEMBL118184',
#  'CHEMBL120041',
#  'CHEMBL118568',
#  'CHEMBL331218',
#  'CHEMBL11662',
#  'CHEMBL121289',
#  'CHEMBL333236',
#  'CHEMBL121043',
#  'CHEMBL120372',
#  'CHEMBL122123',
#  'CHEMBL120228',
#  'CHEMBL338741',
#  'CHEMBL119661',
#  'CHEMBL121507',
#  'CHEMBL339877',
#  'CHEMBL120943',
#  'CHEMBL120370',
#  'CHEMBL120811',
#  'CHEMBL71685',
#  'CHEMBL439790',
#  'CHEMBL120207',
#  'CHEMBL275256',
#  'CHEMBL120165',
#  'CHEMBL121300',
#  'CHEMBL333868',
#  'CHEMBL120284',
#  'CHEMBL120259',
#  'CHEMBL122472',
#  'CHEMBL121314',
#  'CHEMBL121261',
#  'CHEMBL118124',
#  'CHEMBL121304',
#  'CHEMBL326521',
#  'CHEMBL122008',
#  'CHEMBL120947',
#  'CHEMBL118188',
#  'CHEMBL120496',
#  'CHEMBL333237',
#  'CHEMBL120019',
#  'CHEMBL558783',
#  'CHEMBL167372',
#  'CHEMBL354808',
#  'CHEMBL166834',
#  'CHEMBL267473',
#  'CHEMBL168820',
#  'CHEMBL535802',
#  'CHEMBL166731',
#  'CHEMBL165648',
#  'CHEMBL165997',
#  'CHEMBL355614',
#  'CHEMBL166425',
#  'CHEMBL323096',
#  'CHEMBL103348',
#  'CHEMBL100671',
#  'CHEMBL320394',
#  'CHEMBL321358',
#  'CHEMBL3215733',
#  'CHEMBL105386',
#  'CHEMBL420281',
#  'CHEMBL101942',
#  'CHEMBL102243',
#  'CHEMBL105587',
#  'CHEMBL3217077',
#  'CHEMBL3215528',
#  'CHEMBL3217065',
#  'CHEMBL193',
#  'CHEMBL318342',
#  'CHEMBL320388',
#  'CHEMBL3216856',
#  'CHEMBL3216177',
#  'CHEMBL100607',
#  'CHEMBL100780',
#  'CHEMBL105139',
#  'CHEMBL101861',
#  'CHEMBL3216618',
#  'CHEMBL323095',
#  'CHEMBL98611',
#  'CHEMBL101723',
#  'CHEMBL101234',
#  'CHEMBL102156',
#  'CHEMBL267473',
#  'CHEMBL3215555',
#  'CHEMBL555860',
#  'CHEMBL322015',
#  'CHEMBL104156',
#  'CHEMBL319993',
#  'CHEMBL101233',
#  'CHEMBL103656',
#  'CHEMBL312536',
#  'CHEMBL72690',
#  'CHEMBL75609',
#  'CHEMBL296720',
#  'CHEMBL420931',
#  'CHEMBL1743616',
#  'CHEMBL309960',
#  'CHEMBL72684',
#  'CHEMBL76234',
#  'CHEMBL74627',
#  'CHEMBL72070',
#  'CHEMBL73606',
#  'CHEMBL73426',
#  'CHEMBL310904',
#  'CHEMBL73236',
#  'CHEMBL324130',
#  'CHEMBL72273',
#  'CHEMBL114424',
#  'CHEMBL331356',
#  'CHEMBL73779',
#  'CHEMBL310955',
#  'CHEMBL72382',
#  'CHEMBL8273',
#  'CHEMBL75787',
#  'CHEMBL74516',
#  'CHEMBL73620',
#  'CHEMBL74973',
#  'CHEMBL114751',
#  'CHEMBL307725',
#  'CHEMBL73769',
#  'CHEMBL324364',
#  'CHEMBL75451',
#  'CHEMBL554990',
#  'CHEMBL8273',
#  'CHEMBL75449',
#  'CHEMBL307382',
#  'CHEMBL73143',
#  'CHEMBL311689',
#  'CHEMBL74821',
#  'CHEMBL75252',
#  'CHEMBL74693',
#  'CHEMBL74207',
#  'CHEMBL267473',
#  'CHEMBL324364',
#  'CHEMBL72450',
#  'CHEMBL75249',
#  'CHEMBL73158',
#  'CHEMBL73407',
#  'CHEMBL541827',
#  'CHEMBL75334',
#  'CHEMBL324364',
#  'CHEMBL324364',
#  'CHEMBL72923',
#  'CHEMBL1743611',
#  'CHEMBL74733',
#  'CHEMBL73850',
#  'CHEMBL76341',
#  'CHEMBL307631',
#  'CHEMBL1743613',
#  'CHEMBL73065',
#  'CHEMBL75344',
#  'CHEMBL73748',
#  'CHEMBL74915',
#  'CHEMBL439787']

# %% [markdown]
# **Iterate canonical_smiles to a list**

# %%
canonical_smiles =[]
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
canonical_smiles
# Out:
# ['Cn1nc(-c2cncs2)c2ccccc2c1=O',
#  'Cn1nc(-c2cncs2)c2ccccc2c1=O',
#  'O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1',
#  'O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1',
#  'CCn1nc(-c2cccnc2)c2ccccc2c1=O',
#  'CCn1nc(-c2cccnc2)c2ccccc2c1=O',
#  'O=C(NCCCCn1ccnc1)c1ccc(Cl)cc1',
#  'O=C(NCCCCCCCCn1ccnc1)c1ccc(Cl)s1',
#  'CC(CCNC(=O)c1ccc(Cl)s1)n1ccnc1',
#  'O=C(NCCCCn1ccnc1)c1cccs1',
#  'O=C(NCCCn1ccnc1)c1ccc(I)cc1',
#  'CC(CCNC(=O)c1ccc(Cl)nc1)n1ccnc1',
#  'O=C(NCCCCCn1ccnc1)c1cc2cc(Cl)ccc2[nH]1',
#  'O=C(NCCCCCCCCn1ccnc1)c1cc2cc(Cl)ccc2[nH]1',
#  'CC(CCNC(=O)c1cc2cc(Cl)ccc2[nH]1)n1ccnc1',
#  'O=C(NCCCCCn1ccnc1)c1ccc(Cl)s1',
#  'O=C(NCCCn1ccnc1)c1cc2cc(Cl)ccc2s1',
#  'O=C(NCCCCn1ccnc1)c1cc2ccccc2[nH]1',
#  'O=C(O)c1ccc(OCCn2ccnc2)cc1',
#  'CSc1ccc(C(=O)NCCCn2ccnc2)cc1',
#  'O=C(NCCCCCCn1ccnc1)c1ccc(Cl)cc1',
#  'O=C(NCCCCCn1ccnc1)c1ccc(Cl)nc1',
#  'O=C(NCCCCCn1ccnc1)c1ccc(Cl)cc1',
#  'O=C(NCCCCn1ccnc1)c1ccc(Cl)s1',
#  'O=C(NCCCCCCn1ccnc1)c1ccc(Cl)s1',
#  'O=C(NCCCCCn1ccnc1)c1ccc(C(F)(F)F)cc1',
#  'O=C(NCCCn1ccnc1)c1cc(Br)c(Br)s1',
#  'O=C(NCCCn1ccnc1)c1sc2ccccc2c1Cl',
#  'Cc1ccc(C(=O)NCCCn2ccnc2)s1',
#  'O=C(O)c1ccc(OCCn2ccnc2)cc1',
#  'O=C(NCCCCn1ccnc1)c1ccc(Cl)nc1',
#  'O=C(NCCCCCCCCn1ccnc1)c1ccc(Cl)cc1',
#  'O=C(NCCCn1ccnc1)c1cccc(C(F)(F)F)c1',
#  'O=C(NCCCn1ccnc1)c1ccc(Cl)s1',
#  'O=C(NCCCn1ccnc1)c1cc2ccccc2o1',
#  'CNC(=O)N(O)CC1=Cc2cc(Oc3ccc(F)cc3)ccc2OC1',
#  'CC(c1cc2ccccc2s1)N(O)C(N)=O',
#  'NC(=O)N(O)CC1=Cc2cc(Oc3ccccc3)ccc2OC1',
#  'O=C(O)C1CCc2cc(Cn3ccnc3)sc2C1',
#  'O=C(O)c1ccc(OCCn2ccnc2)cc1',
#  'O=C(O)C1=Cc2sc(Cn3ccnc3)cc2CC1',
#  'CC(C)(CCO/N=C(\\c1ccccc1)C(Cc1ccccc1)n1ccnc1)CC(=O)O',
#  'C/C(=N\\OCCCCC(=O)O)C(Cc1ccccc1)n1ccnc1',
#  'Cc1ccc(CC(/C(=N/OCCCCC(=O)O)C2CCCCC2)n2ccnc2)cc1',
#  'O=C(O)CCCCO/N=C(/c1cccnc1)c1cccc(C(F)(F)F)c1',
#  'CCCCCC/C(Cn1ccnc1)=N\\OCCCCC(=O)O',
#  'O=C(O)CCCCO/N=C(/C1CCCCC1)C(Cc1ccccc1)n1ccnc1',
#  'CS(=O)(=O)c1ccc(CC(/C(=N/OCCCCC(=O)O)C2CCCCC2)n2ccnc2)cc1',
#  'CCCCCC/C(Cn1ccnc1)=N/OCCCCC(=O)O',
#  'O=C(O)CCCO/N=C(/Cn1ccnc1)C1CCCCC1',
#  'CC(/C(=N\\OCCCCC(=O)O)c1ccccc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(/Cn1ccnc1)C1CCCCC1',
#  'O=C(O)CCCCO/N=C(\\c1ccccc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1ccc(F)cc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(CC1CCCCC1)n1ccnc1',
#  'COc1ccc(CC(/C(=N/OCCCCC(=O)O)C2CCCCC2)n2ccnc2)cc1',
#  'O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1',
#  'CS(=O)(=O)c1ccc(/C(=N\\OCCCCC(=O)O)C(Cc2ccccc2)n2ccnc2)cc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1ccccc1F)n1ccnc1',
#  'CCOC(=O)CCCCO/N=C(\\C1CCCCC1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCO/N=C(\\Cn1ccnc1)c1ccccc1',
#  'O=C(O)CCCCO/N=C(/c1ccccc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1ccccn1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1cnccn1)n1ccnc1',
#  'CSc1ccc(/C(=N\\OCCCCC(=O)O)C(Cc2ccccc2)n2ccnc2)cc1',
#  'O=C(O)CCCCO/N=C(\\Cn1ccnc1)c1ccccc1',
#  'O=C(O)CCCCO/N=C(\\c1ccccc1)C(Cc1ccc(Cl)cc1)n1ccnc1',
#  'O=C(O)COCCO/N=C(\\c1ccccc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCCCO/N=C(\\Cn1ccnc1)c1ccccc1',
#  'CC(C)(CCCO/N=C(\\c1ccccc1)C(Cc1ccccc1)n1ccnc1)C(=O)O',
#  'O=C(O)Cc1ccc(CCNS(=O)(=O)c2ccc(Cl)cc2)cc1',
#  'O=C(O)CCCCO/N=C(\\Cn1ccnc1)C1CCCCC1',
#  'O=C(O)CCCCO/N=C(/C1CCCCC1)C(Cc1cccc(F)c1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1ccc(C(F)(F)F)cc1)n1ccnc1',
#  'O=C(O)/C=C/CCO/N=C(\\c1ccccc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCO/N=C(\\Cn1ccnc1)C1CCCCC1',
#  'CC(/C(=N/OCCCCC(=O)O)c1ccccc1)n1ccnc1',
#  'O=C(O)CCCCCO/N=C(\\c1ccccc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1ccco1)n1ccnc1',
#  'O=C(CCCCO/N=C(\\C1CCCCC1)C(Cc1ccccc1)n1ccnc1)NO',
#  'O=C(O)CCCCCO/N=C(\\Cn1ccnc1)C1CCCCC1',
#  'O=C(O)CCCCO/N=C(\\Cn1ccnc1)c1ccccn1',
#  'O=C(O)CCCCCO/N=C(/c1ccccc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\c1ccc(Br)cc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)/C=C/CCCO/N=C(\\c1ccccc1)C(Cc1ccccc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(/c1ccccc1)C(Cc1ccc(F)cc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(/Cn1ccnc1)c1ccccc1',
#  'O=C(O)CCCCO/N=C(\\c1ccccc1)C(Cc1ccc(F)cc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(/c1ccccc1)C(Cc1ccc(Cl)cc1)n1ccnc1',
#  'O=C(O)CCCCO/N=C(\\C1CCCCC1)C(Cc1cccc(F)c1)n1ccnc1',
#  'CCCCCC/C(=N\\OCCCCC(=O)O)C(Cc1ccccc1)n1ccnc1',
#  'Cl.O=C1c2ccccc2C(=O)N1CCCCCn1ccnc1',
#  'O=C1c2ccccc2C(=O)N1CCCCCCn1ccnc1',
#  'Cc1cccc2c1C(=O)N(CCCn1ccnc1)C2=O',
#  'O=C1c2ccccc2C(=O)N1CCCCCCCCn1ccnc1',
#  'O=C(O)c1ccc(OCCn2ccnc2)cc1',
#  'O=C1c2ccccc2C(=O)N1CCCn1ccnc1',
#  'Cc1cccc2c1C(=O)N(CCCCn1ccnc1)C2=O.Cl',
#  'O=C1c2ccccc2C(=O)N1CCCCCCCCCCn1ccnc1',
#  'O=C1c2cccc(Br)c2C(=O)N1CCCCCn1ccnc1',
#  'O=C1c2cccc(Br)c2C(=O)N1CCCCn1ccnc1',
#  'O=C1c2ccc(Cl)c(Cl)c2C(=O)N1CCCn1ccnc1',
#  'O=C1c2ccccc2C(=O)N1CCCCn1ccnc1',
#  'CCOC(=O)C1=C(C)N(C)C(C)=C(C(=O)OCC)C1c1cccc(-n2ccnc2)c1',
#  'CCO/C(O)=C1\\C(COC)=NC(C)=C(C(=O)OC)C1c1cccc(-n2ccnc2)c1',
#  'CO/C(O)=C1\\C(C)=NC(C)=C(C(C)=O)C1c1cccc(-n2ccnc2)c1',
#  'Cc1cc(O)c(C)c2sc(NCc3cccnc3)nc12',
#  'Cc1c(O)c2ccccc2c2nc(NCc3cccnc3)sc12',
#  'CNc1nc2c(C)c(Cc3cccnc3)c(O)c(C)c2s1.Cl.Cl',
#  'CCNc1nc2c(C)c(C)c(O)c(Cc3cccnc3)c2s1',
#  'COc1cc2nc(NCc3cccnc3)sc2c(OC)c1O',
#  'CCO/C(O)=C1\\C(C)=NC(C)=C(C(=O)OCCN(C)Cc2ccccc2)C1c1cccc(-c2cccnc2)c1',
#  'Cc1c(O)c(C)c2sc(NCc3cccnc3)nc2c1C',
#  'CCNc1nc2c(C)c(Cc3cccnc3)c(O)c(C)c2s1',
#  'CCNc1nc2c(Cc3cccnc3)c(C)c(O)c(C)c2s1.Cl.Cl',
#  'CNc1nc2c(Cc3cccnc3)c(OC)c(O)c(C)c2s1.Cl.Cl',
#  'CCc1c(O)c(OC)c(Cc2cccnc2)c2nc(N)sc12.Cl.Cl',
#  'COC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1ccccc1[N+](=O)[O-]',
#  'CCOC(=O)C1=C(C)N=C(C)/C(=C(/O)OCC)C1c1ccc(-n2ccnc2)cc1',
#  'CCO/C(O)=C1\\C(COCCNC(=O)c2ccccc2C(=O)O)=NC(C)=C(C(=O)OC)C1c1cccc(-n2ccnc2)c1',
#  'Cc1c(O)c(C)c2sc(N)nc2c1Cc1cccnc1.Cl.Cl',
#  'Cc1c(O)c(Cc2cccnc2)c2sc(N)nc2c1C.Cl.Cl',
#  'CCOC(=O)C1=C(C)N=C(C)/C(=C(/O)OCC)C1c1ccccc1-n1ccnc1',
#  'CCO/C(O)=C1\\C(C)=NC(C)=C(C(=O)OCCN(C)Cc2ccccc2)C1c1cccc(-n2ccnc2)c1',
#  'CNc1nc2c(Cc3cccnc3)c(C)c(O)c(C)c2s1',
#  'CC1=NC(C)=C(C(=O)OCC(C)C)C(c2cccc(-c3cccnc3)c2)/C1=C(\\O)OCC(C)C',
#  'COc1c(O)c(C)c2sc(N)nc2c1Cc1cccnc1.Cl.Cl',
#  'COC(=O)C1=C(C)N=C(C)/C(=C(/O)OC)C1c1cccc(-n2ccnc2)c1',
#  'CCO/C(O)=C1\\C(COCCN)=NC(C)=C(C(=O)OC)C1c1cccc(-n2ccnc2)c1',
#  'CCOC(=O)C1=C(C)N=C(C)/C(=C(/O)OCC)C1c1cccc(-c2cccnc2)c1',
#  'CCO/C(O)=C1\\C(C)=NC(C)=C(C(=O)O)C1c1cccc(-n2ccnc2)c1',
#  'CCOC(=O)C1=C(CC)N=C(CC)/C(=C(/O)OCC)C1c1cccc(-n2ccnc2)c1',
#  'O=C(O)c1ccc(OCCn2ccnc2)cc1',
#  'CCCNc1nc2c(Cc3cccnc3)c(C)c(O)c(C)c2s1.Cl.Cl',
#  'CCOC(=O)c1c(C)nc(C)c(C(=O)OCC)c1-c1cccc(-n2ccnc2)c1.Cl.Cl',
#  'Oc1cc(-c2ccccc2)c2nc(NCc3cccnc3)sc2c1',
#  'CCc1c(O)c(OC)c(Cc2cccnc2)c2nc(NC)sc12',
#  'CCO/C(O)=C1\\C(C)=NC(C)=C(C(=O)OC)C1c1cccc(-n2ccnc2)c1',
#  'CCOC(=O)C1=C(C)N=C(C)/C(=C(/O)OCC)C1c1cccc(-n2ccnc2)c1',
#  'CCOC(=O)C1=C(C)N=C(C)/C(=C(/O)OCC)C1c1cccc(Cn2ccnc2)c1',
#  'O=c1[nH]c2ccccc2c(=O)n1CCCCCn1ccnc1',
#  'O=c1[nH]c2ccc(Br)cc2c(=O)n1CCCCn1ccnc1',
#  'O=c1[nH]c2c(C(F)(F)F)cccc2c(=O)n1CCCCn1ccnc1',
#  'O=C(O)c1ccc2c(c1)C(SCCNS(=O)(=O)c1cccnc1)c1ccccc1CO2',
#  'Cc1ccc2[nH]c(=O)n(CC(C)Cn3ccnc3)c(=O)c2c1',
#  'Cl.O=c1c2ccccc2nnn1CCCCCCn1ccnc1',
#  'O=c1[nH]c2ccc(Cl)cc2c(=O)n1CCCCCCCn1ccnc1',
#  'O=c1[nH]c2ccc(Cl)cc2c(=O)n1CCCCCCCCCCn1ccnc1',
#  'CC(Cn1ccnc1)Cn1c(=O)[nH]c2cc(Cl)ccc2c1=O',
#  'CC(Cn1ccnc1)Cn1c(=O)[nH]c2c(Cl)cccc2c1=O',
#  'O=c1c2cc(Cl)ccc2ncn1CCCCn1ccnc1',
#  'CC(CCn1cnc2ccc(Cl)cc2c1=O)n1ccnc1',
#  'O=c1[nH]c2ccccc2c(=O)n1CCCCCCn1ccnc1',
#  'O=c1[nH]c2ccc(Br)cc2c(=O)n1CCCn1ccnc1',
#  'O=c1c2cc(Cl)ccc2ncn1CCCCCCCCn1ccnc1',
#  'O=C(O)c1ccc2c(c1)C(SCCNS(=O)(=O)c1ccccc1)c1ccccc1CO2',
#  'O=c1c2ccccc2nnn1CCCn1ccnc1',
#  'CN(CCSC1c2ccccc2COc2ccc(C(=O)O)cc21)S(=O)(=O)c1ccccc1',
#  'O=C(O)c1ccc2c(c1)OCc1ccccc1C2SCCNS(=O)(=O)c1ccccc1',
#  'CC(CCn1c(=O)[nH]c2ccccc2c1=O)n1ccnc1',
#  'O=c1[nH]c2cc(Cl)ccc2c(=O)n1CCCn1ccnc1',
#  'Cc1ccc2[nH]c(=O)n(CCCCn3ccnc3)c(=O)c2c1',
#  'O=C(O)COc1ccc(CCNS(=O)(=O)c2ccccc2)cc1',
#  'O=c1[nH]c2ccc(Cl)cc2c(=O)n1CCCCn1ccnc1',
#  'O=c1[nH]c2cc(Cl)ccc2c(=O)n1CCCCCn1ccnc1',
#  'O=c1[nH]c2c(Cl)cccc2c(=O)n1CCCCn1ccnc1',
#  'Cc1ccc(N)c(C(=O)NCCC(C)n2ccnc2)c1',
#  'O=C(NCCSC1c2ccccc2COc2ccc(C(=O)O)cc21)Nc1ccccc1',
#  'Cc1ccc2[nH]c(=O)n(CCCn3ccnc3)c(=O)c2c1',
#  'Cc1ccc2[nH]c(=O)n(CCC(C)n3ccnc3)c(=O)c2c1',
#  'O=C(O)c1ccc2c(c1)C(SCCNS(=O)(=O)/C=C/c1ccccc1)c1ccccc1CO2',
#  'Cc1ccc2[nH]c(=O)n(CCCCCn3ccnc3)c(=O)c2c1',
#  'CC(Cn1ccnc1)Cn1c(=O)[nH]c2ccc(Cl)cc2c1=O.Cl',
#  'O=C(O)COc1ccc(CCNS(=O)(=O)c2ccccc2)cc1',
#  'CC(CCn1c(=O)[nH]c2ccc(Cl)cc2c1=O)n1ccnc1',
#  'O=c1[nH]c2cc(Cl)ccc2c(=O)n1CCCCCCn1ccnc1',
#  'O=c1[nH]c2ccc(Cl)cc2c(=O)n1CCCCCn1ccnc1',
#  'CC(CNC(=O)c1cc(Cl)ccc1N)Cn1ccnc1',
#  'CC(CCNC(=O)c1cc(Cl)ccc1N)n1ccnc1',
#  'Cc1ccc2ncn(CCCCn3ccnc3)c(=O)c2c1',
#  'Cc1ccc(N)c(C(=O)NCC(C)Cn2ccnc2)c1',
#  'CC(Cn1ccnc1)Cn1c(=O)[nH]c2c(C(F)(F)F)cccc2c1=O',
#  'O=C(O)c1ccc(OCCn2ccnc2)cc1',
#  'O=C(O)c1ccc2c(c1)C(SCCNS(=O)(=O)/C=C/c1ccccc1)c1ccccc1CO2',
#  'O=c1[nH]c2ccc(Cl)cc2c(=O)n1CCCCCCn1ccnc1',
#  'CC(CNC(=O)c1cc(Br)ccc1N)Cn1ccnc1',
#  'O=c1[nH]c2c(Cl)cccc2c(=O)n1CCCCCn1ccnc1',
#  'O=c1c2cc(Cl)ccc2nnn1CCCCn1ccnc1',
#  'Cl.O=c1[nH]c2ccc(Cl)cc2c(=O)n1CCCCn1ccnc1',
#  'O=c1[nH]c2ccccc2c(=O)n1CCCn1ccnc1',
#  'O=C(O)c1ccc2c(c1)C(SCCNS(=O)(=O)/C=C/c1ccccc1)c1ccccc1CO2',
#  'O=C(O)c1ccc2c(c1)C(SCCNS(=O)(=O)/C=C/c1ccccc1)c1ccccc1CO2',
#  'CC(CNC(=O)c1ccccc1N)Cn1ccnc1',
#  'CC(Cn1ccnc1)Cn1nnc2ccc(Cl)cc2c1=O.Cl',
#  'CC(Cn1ccnc1)Cn1c(=O)[nH]c2ccc(Cl)cc2c1=O',
#  'CC(Cn1ccnc1)Cn1nnc2ccc(Br)cc2c1=O',
#  'O=c1[nH]c2cc(Cl)ccc2c(=O)n1CCCCn1ccnc1',
#  'O=c1[nH]c2c(C(F)(F)F)cccc2c(=O)n1CCCCCn1ccnc1',
#  'Cc1ccc2nnn(CCCCn3ccnc3)c(=O)c2c1.Cl',
#  'CC(Cn1ccnc1)Cn1c(=O)[nH]c2ccccc2c1=O',
#  'CC(CCn1c(=O)[nH]c2c(Cl)cccc2c1=O)n1ccnc1',
#  'CC(Cn1ccnc1)Cn1cnc2ccc(Cl)cc2c1=O',
#  'Cc1ccc(N)c(C(=O)NCCCCn2ccnc2)c1',
#  'COc1cccc(OC)c1C(=O)NCCSC1c2ccccc2COc2ccc(C(=O)O)cc21']

# %% [markdown]
#  **Iterate standard_value to a list**

# %%
standard_value =[]
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL130453                        Cn1nc(-c2cncs2)c2ccccc2c1=O
# 1         CHEMBL130453                        Cn1nc(-c2cncs2)c2ccccc2c1=O
# 2          CHEMBL11662                      O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1
# 3          CHEMBL11662                      O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1
# 4         CHEMBL335687                      CCn1nc(-c2cccnc2)c2ccccc2c1=O
# ..                 ...                                                ...
# 200        CHEMBL73065               CC(Cn1ccnc1)Cn1c(=O)[nH]c2ccccc2c1=O
# 201        CHEMBL75344           CC(CCn1c(=O)[nH]c2c(Cl)cccc2c1=O)n1ccnc1
# 202        CHEMBL73748                  CC(Cn1ccnc1)Cn1cnc2ccc(Cl)cc2c1=O
# 203        CHEMBL74915                    Cc1ccc(N)c(C(=O)NCCCCn2ccnc2)c1
# 204       CHEMBL439787  COc1cccc(OC)c1C(=O)NCCSC1c2ccccc2COc2ccc(C(=O)...
#
#     standard_value
# 0            300.0
# 1           3300.0
# 2            200.0
# 3            200.0
# 4           1300.0
# ..             ...
# 200           30.0
# 201         1000.0
# 202           90.0
# 203          340.0
# 204          850.0
#
# [205 rows x 3 columns]

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL130453                        Cn1nc(-c2cncs2)c2ccccc2c1=O
# 1         CHEMBL130453                        Cn1nc(-c2cncs2)c2ccccc2c1=O
# 2          CHEMBL11662                      O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1
# 3          CHEMBL11662                      O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1
# 4         CHEMBL335687                      CCn1nc(-c2cccnc2)c2ccccc2c1=O
# ..                 ...                                                ...
# 200        CHEMBL73065               CC(Cn1ccnc1)Cn1c(=O)[nH]c2ccccc2c1=O
# 201        CHEMBL75344           CC(CCn1c(=O)[nH]c2c(Cl)cccc2c1=O)n1ccnc1
# 202        CHEMBL73748                  CC(Cn1ccnc1)Cn1cnc2ccc(Cl)cc2c1=O
# 203        CHEMBL74915                    Cc1ccc(N)c(C(=O)NCCCCn2ccnc2)c1
# 204       CHEMBL439787  COc1cccc(OC)c1C(=O)NCCSC1c2ccccc2COc2ccc(C(=O)...
#
#     standard_value bioactivity_class
# 0            300.0            active
# 1           3300.0          inactive
# 2            200.0            active
# 3            200.0            active
# 4           1300.0          inactive
# ..             ...               ...
# 200           30.0            active
# 201         1000.0            active
# 202           90.0            active
# 203          340.0            active
# 204          850.0            active
#
# [205 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df4.to_csv('bioactivity_data_preprocessed.csv', index=False)

# %%
df4.shape
# Out:
# (205, 4)

# %%
! ls -l
# Out:
# total 120
# -rw-r--r-- 1 root root 13773 Jan 20 22:29 bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 96462 Jan 20 22:14 bioactivity_data_raw.csv
# drwx------ 6 root root  4096 Jan 20 22:14 gdrive
# drwxr-xr-x 1 root root  4096 Jan 16 14:29 sample_data

# %%
! cp bioactivity_data_preprocessed.csv "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# bioactivity_data_preprocessed.csv  bioactivity_data_raw.csv

# %% [markdown]
# ---
